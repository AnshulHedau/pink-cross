# %%
import pyrebase
import random
import time
min_support_count = 0.035
# Firebase configuration
config = {
    "apiKey": "AIzaSyDDVJIFHI-xXAb2CNgjHWU5VTbTwTCcLMs",
    "authDomain": "flyingpanda-41a88.firebaseapp.com",
    "databaseURL": "https://flyingpanda-41a88.firebaseio.com",
    "projectId": "flyingpanda-41a88",
    "storageBucket": "flyingpanda-41a88.appspot.com"
}
firebase = pyrebase.initialize_app(config)
db = firebase.database()

# %%
location_names = ['Bhopal','Chennai','Delhi','Bangalore','Kolkata']
mobile_names = ['9406539777','8002746733','8770961697','7488501104','8092460585',"7653541209",'9742747429',
                '9406539776','8002742733','9770961697','7408501104','8022460585',"7653141209",'9748657429']
category_names = ['food','shops','cabs']
vendor_names = [['Dominos','McD','Subway','Baskin Robins'],['Maxx','V-Mart','Reliance','Adidas'],['Ola','Meru','Uber','OTS']]
flight_names = ['Air India','Indigo','Spice Jet']
for i in range(0,1000):
    location = random.randint(0,4)
    category = random.randint(0,2)
    vendor = random.randint(0,3)
    flight = random.randint(0,2)
    mobile = random.randint(0,13)
    location_input = location_names[location]
    mobile_input = mobile_names[mobile]
    unique_id = str(round(time.time() * 1000))
    category_input = category_names[category]
    vendor_input = vendor_names[category][vendor]
    input_data = {"category": category, "vendor": vendor_input, "Flight": flight_names[flight]}
    print(input_data)
    db.child("data").child(mobile_input).child(location_input).child(unique_id).set(input_data)
# Out:
# {'category': 0, 'vendor': 'Subway', 'Flight': 'Indigo'}
# {'category': 2, 'vendor': 'Ola', 'Flight': 'Spice Jet'}
# {'category': 0, 'vendor': 'Subway', 'Flight': 'Spice Jet'}
# {'category': 1, 'vendor': 'V-Mart', 'Flight': 'Indigo'}
# {'category': 0, 'vendor': 'Baskin Robins', 'Flight': 'Air India'}
# {'category': 1, 'vendor': 'Reliance', 'Flight': 'Air India'}
# {'category': 1, 'vendor': 'V-Mart', 'Flight': 'Indigo'}
# {'category': 1, 'vendor': 'Adidas', 'Flight': 'Spice Jet'}
# {'category': 2, 'vendor': 'OTS', 'Flight': 'Air India'}
# {'category': 2, 'vendor': 'Ola', 'Flight': 'Spice Jet'}
# {'category': 0, 'vendor': 'McD', 'Flight': 'Spice Jet'}
# {'category': 0, 'vendor': 'McD', 'Flight': 'Spice Jet'}
# {'category': 1, 'vendor': 'Maxx', 'Flight': 'Spice Jet'}
# {'category': 2, 'vendor': 'OTS', 'Flight': 'Indigo'}
# {'category': 2, 'vendor': 'Meru', 'Flight': 'Air India'}
# {'category': 1, 'vendor': 'Maxx', 'Flight': 'Spice Jet'}
# ...

# %%
all_users = db.child("data").get()
lines = []
for user in all_users.each():
    #print(user.key()) 
    for item in user.val():
        old_timestamp = 0
        #print(item)  
        for timestmp in user.val()[item]:
            if(int(timestmp)-old_timestamp > 200000):
                #print(timestmp)
                if(len(line)>2):
                    lines.append(list(line))
                line = [item]
                line.append(user.val()[item][timestmp]["Flight"])
                line.append(user.val()[item][timestmp]["vendor"])
            else:
                line.append(user.val()[item][timestmp]["vendor"])
            old_timestamp = int(timestmp)
        if(len(line)>2):
            lines.append(list(line))     
        line = [item]
print(lines)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      74
# ---> 75     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      76         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# ...

# %%
import csv
with open('dataset.csv', 'w',newline='') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(lines)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(lines).transform(lines)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      Adidas  Air India  Bangalore  Baskin Robins  Bhopal  Chennai  Delhi  \
# 0      True      False       True          False   False    False  False
# 1     False       True       True          False   False    False  False
# 2     False      False       True          False   False    False  False
# 3     False      False       True          False   False    False  False
# 4     False      False       True          False   False    False  False
# 5      True      False      False          False    True    False  False
# 6     False       True      False          False    True    False  False
# 7     False      False      False          False    True    False  False
# 8      True      False      False          False    True    False  False
# 9     False      False      False          False    True    False  False
# 10    False      False      False           True    True    False  False
# 11    False      False      False          False   False     True  False
# ...

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df, min_support=min_support_count, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# %%
frequent_itemsets[ (frequent_itemsets['length'] > 2) &
                   (frequent_itemsets['support'] >= min_support_count) ].sort_values('support',ascending=False)
# Out:
#       support                         itemsets  length
# 204  0.048232                (Uber, Ola, Maxx)       3
# 189  0.041801             (Maxx, Meru, Adidas)       3
# 194  0.041801           (Uber, V-Mart, Adidas)       3
# 216  0.041801              (Uber, Ola, V-Mart)       3
# 205  0.041801              (V-Mart, Ola, Maxx)       3
# 192  0.041801         (Uber, Reliance, Adidas)       3
# 193  0.038585        (Uber, Spice Jet, Adidas)       3
# 202  0.038585             (V-Mart, Meru, Maxx)       3
# 219  0.038585        (Uber, Spice Jet, V-Mart)       3
# 214  0.038585            (Uber, Ola, Reliance)       3
# 206  0.038585             (Uber, Subway, Maxx)       3
# 190  0.038585           (Subway, Maxx, Adidas)       3
# 207  0.038585             (Uber, Maxx, V-Mart)       3
# 201  0.038585               (Uber, Meru, Maxx)       3
# 197  0.038585  (Reliance, Baskin Robins, Meru)       3
# 212  0.035370              (Uber, OTS, V-Mart)       3
# ...

# %%
for item in (frequent_itemsets[ (frequent_itemsets['length'] > 2) &
                   (frequent_itemsets['support'] >= min_support_count) ].sort_values('support',ascending=False)['itemsets']):
    print(list(item))
# Out:
# ['Uber', 'Ola', 'Maxx']
# ['Maxx', 'Meru', 'Adidas']
# ['Uber', 'V-Mart', 'Adidas']
# ['Uber', 'Ola', 'V-Mart']
# ['V-Mart', 'Ola', 'Maxx']
# ['Uber', 'Reliance', 'Adidas']
# ['Uber', 'Spice Jet', 'Adidas']
# ['V-Mart', 'Meru', 'Maxx']
# ['Uber', 'Spice Jet', 'V-Mart']
# ['Uber', 'Ola', 'Reliance']
# ['Uber', 'Subway', 'Maxx']
# ['Subway', 'Maxx', 'Adidas']
# ['Uber', 'Maxx', 'V-Mart']
# ['Uber', 'Meru', 'Maxx']
# ['Reliance', 'Baskin Robins', 'Meru']
# ['Uber', 'OTS', 'V-Mart']
# ['Baskin Robins', 'Meru', 'Indigo']
# ['Uber', 'Reliance', 'V-Mart']
# ['Uber', 'Subway', 'Reliance']
# ['Uber', 'Meru', 'Adidas']
# ['Subway', 'Ola', 'Spice Jet']
# ['Ola', 'Reliance', 'Spice Jet']
# ['Uber', 'Meru', 'V-Mart']
# ['Subway', 'Ola', 'Maxx']
# ['Uber', 'Subway', 'Meru']
# ['Reliance', 'Meru', 'Spice Jet']
# ['Reliance', 'OTS', 'Meru']
# ['Uber', 'Subway', 'Air India']
# ['Subway', 'Baskin Robins', 'Meru']
# ['Dominos', 'Spice Jet', 'V-Mart']
# ['Subway', 'Meru', 'Maxx']
# ...
